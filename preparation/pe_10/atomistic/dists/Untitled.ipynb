# %%
import mdtraj

# %%
pe10_traj = mdtraj.load('pe10_run2.xtc', top='conf.gro')

# %%
res_pe10_traj = mdtraj.load('pe10_run2.xtc', top='conf.gro')

# %%
end_end_atoms_id = pe10_traj.topology.select('name C99 or name C100').reshape(75, 2)

# %%
end_end_traj = pe10_traj.atom_slice(end_end_atoms_id.reshape(150,))

# %%
pe10_traj.topology?

# %%
plt.hist(mdtraj.compute_rg(pe10_traj, ))
# Out:
# (array([   2.,   12.,   55.,  222.,  439.,  602.,  423.,  181.,   57.,    8.]),
#  array([ 3.08215252,  3.08549945,  3.08884639,  3.09219332,  3.09554026,
#          3.09888719,  3.10223413,  3.10558106,  3.108928  ,  3.11227493,
#          3.11562187]),
#  <a list of 10 Patch objects>)

# %%
mdtraj.compute_rg?

# %%
plt.hist(np.average(mdtraj.compute_distances(pe10_traj, end_end_atoms_id), axis=1))
# Out:
# (array([   7.,   27.,   88.,  289.,  515.,  517.,  358.,  133.,   46.,   21.]),
#  array([ 2.70883632,  2.76731393,  2.82579155,  2.88426917,  2.94274678,
#          3.0012244 ,  3.05970201,  3.11817963,  3.17665725,  3.23513486,
#          3.29361248]),
#  <a list of 10 Patch objects>)
